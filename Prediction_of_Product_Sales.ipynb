# %% [markdown]
# <a href="https://colab.research.google.com/github/bayan2002/Prediction-of-Product-Sales/blob/main/Prediction_of_Product_Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Project Title: Prediction of Product Sales

# %%
# - Author: Bayan Abd El Bary

# %%
## Project Overview

# %%
## Load and Inspect Data

# %%
## Clean Data

# %%
## Feature Inspection

# %%
## Feature Inspection
